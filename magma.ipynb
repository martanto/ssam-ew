# %%
import os
import pandas as pd
from magma import Magma

# %%
token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..wPt4DPu_hXahbuCzFRzJRdSEU-wMb_8hkrYT6lAyaLo'

# %%
magma = Magma(
    token = token,
    volcano_code = 'SMR',
    start_date = '2024-01-01',
    end_date = '2024-04-30',
    earthquake_events = ['*']
)

# %%
df = magma.df

# %%
df

# %%
magma.plot(
    interval=7
)

# %%
csv_magma = os.path.join(os.getcwd(), 'output', 'magma_SMR_2024-01-01_2024-04-30.csv')
df = pd.read_csv(csv_magma, index_col='date', parse_dates=True)

magma_static = Magma.plot_from_df(df, interval=7)
