# %%
import os
import magma
import json
import requests
from pathlib import Path

# %%
token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..q3b0aAKQuPsZsN97T6W20cifTJFDiWTo792cbMMCFMY'

# %%
auth = magma.Auth(token=token, username='198803152015031005', password='antoanto')
# Out:
# ✅ Authenticated. Selamat datang di API MAGMA Indonesia

# %%
token = auth.token

# %%
plot = magma.Plot(
    token =  token,
    volcano_code = 'KRA',
    start_date = '2024-01-01',
    end_date = '2024-04-30',
    earthquake_events = ['*']
)
# Out:
# ✅ Authenticated. Selamat datang di API MAGMA Indonesia
# 💾 Saved to D:\Projects\ssam-ew\output\magma_KRA_2024-01-01_2024-04-30.csv

# %%
plot

# %%
plot.show(
    interval = 14, 
    width = 0.5,
    save_plot = True,
    title = 'Kegempaan Krakatau',
    dpi = 300
)
# Out:
# (<Figure size 1200x900 with 9 Axes>,
#  array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >, <Axes: >, <Axes: >], dtype=object))

# %%
plot.token
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..q3b0aAKQuPsZsN97T6W20cifTJFDiWTo792cbMMCFMY'
